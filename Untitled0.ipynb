# %%
# Paso 1: Importar las librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar el CSV en un DataFrame de pandas
mamiferos_acg = pd.read_csv('https://gist.githubusercontent.com/geociencias98/4698f49cc870bfc70415bac5d5e11a6c/raw/cbf979bcd6f4809d03ba40b4d2ffbf6521449909/gistfile1.txt')

# Mostrar las primeras filas para verificar la carga
mamiferos_acg.head()
# Out:
#          id observed_on   latitude  longitude  scientific_name  \
# 0   9293442  12/28/2017  10.876294 -85.722541  Tapirus bairdii
# 1  10228448    3/2/2018  10.981002 -85.759022  Tapirus bairdii
# 2  18044298   11/1/2018  10.699545 -85.248348  Tapirus bairdii
# 3  19287239  12/28/2018  10.833085 -85.705966  Tapirus bairdii
# 4  19303033  12/28/2018  10.944128 -85.642006  Tapirus bairdii
#
#              common_name iconic_taxon_name  taxon_id    year
# 0  Tapir Centroamericano          Mammalia     43355  2017.0
# 1  Tapir Centroamericano          Mammalia     43355  2018.0
# 2  Tapir Centroamericano          Mammalia     43355  2018.0
# 3  Tapir Centroamericano          Mammalia     43355  2018.0
# 4  Tapir Centroamericano          Mammalia     43355  2018.0

# %%
# Filtrar los avistamientos de venados por el valor en 'taxon_id' igual a 42223
venados_acg = mamiferos_acg[mamiferos_acg['taxon_id'] == 42223]

# Contar el número de avistamientos por año
avistamientos_venados = venados_acg['year'].value_counts().sort_index()

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(avistamientos_venados.index, avistamientos_venados.values, color='blue', alpha=0.7)
plt.title('Cantidad de Avistamientos de Venados por Año')
plt.xlabel('Año')
plt.ylabel('Número de Avistamientos')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %%
# Gráfico 2: Cantidad de avistamientos de cada una de las 3 especies principales
especies_principales = mamiferos_acg['common_name'].value_counts().nlargest(3)

plt.figure(figsize=(10, 6))
especies_principales.plot(kind='bar', color=['blue', 'green', 'red'])
plt.title('Avistamientos de las 3 Especies Principales')
plt.xlabel('Especie')
plt.ylabel('Número de Avistamientos')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtrar los avistamientos de venados por el valor en 'taxon_id' igual a 43355
tapir_acg = mamiferos_acg[mamiferos_acg['taxon_id'] == 43355]

# Contar el número de avistamientos por año
avistamientos_tapir = tapir_acg['year'].value_counts().sort_index()

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(avistamientos_tapir.index, avistamientos_tapir.values, color='green', alpha=0.7)
plt.title('Cantidad de Avistamientos de Tapir por Año')
plt.xlabel('Año')
plt.ylabel('Número de Avistamientos')
plt.grid(True)

# Mostrar el gráfico
plt.show()
